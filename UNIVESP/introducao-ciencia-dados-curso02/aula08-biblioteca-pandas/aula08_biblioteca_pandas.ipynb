# %% [markdown]
# # BIBLIOTECA PANDAS

# %% [markdown]
# ## Importar Bibliotecas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series (observe o índice do lado esquerdo)

# %%
s1 = pd.Series([1, 2, -5, 0])
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1,  2, -5,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2 = pd.Series([1, 2, -5, 0], index=["a", "b", "c", "d"])
s2
s2.values
s2.index
s2
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2["a"] = 1000
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %% [markdown]
# ## Comparação

# %%
s2[s2 > 0]
# Out:
# a    1000
# b       2
# dtype: int64

# %% [markdown]
# ## Álgebra

# %%
sr1 = pd.Series([1, 2, 3, 4, 5])
sr2 = pd.Series([5, 4, 3, 2, 1])
sr1 + sr2
sr1 - sr2
sr1 * sr2
sr1 / sr2
# Out:
# 0    0.2
# 1    0.5
# 2    1.0
# 3    2.0
# 4    5.0
# dtype: float64

# %%
s2.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ### Criar DataFrame

# %%
dados = {"estado":["SP","MG","PR","SP","MG","PR"], "ano":[2019,2019,2019,2020,2020,2020], "pop":[45.9, 21.2, 16.9, 46.6, 21.4, 17.3]}
df1 = pd.DataFrame(dados)
df1
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.head()
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4

# %%
df1.tail()
# Out:
#   estado   ano   pop
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.sample(2)
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 4     MG  2020  21.4

# %% [markdown]
# ## Novo DataFrame Baseado no Anterior (veja as colunas)

# %%
df1
df2 = pd.DataFrame(dados, columns=["ano", "estado", "pop"])
df2
# Out:
#     ano estado   pop
# 0  2019     SP  45.9
# 1  2019     MG  21.2
# 2  2019     PR  16.9
# 3  2020     SP  46.6
# 4  2020     MG  21.4
# 5  2020     PR  17.3

# %%
df2["estado"]
df2.estado
df2.dtypes
# Out:
# ano         int64
# estado     object
# pop       float64
# dtype: object

# %% [markdown]
# ## Atribuir Valores

# %%
df2["estimativa"] = 50
df2
df2["estimativa"] = np.arange(6)
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df2["estimativa"][0] = 100
df2
# Out:
# <ipython-input-120-9ea551a847e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["estimativa"][0] = 100
#     ano estado   pop  estimativa
# 0  2019     SP  45.9         100
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df2["nao parana"] = (df2["estado"] != "PR")
df2
# Out:
#     ano estado   pop  estimativa  nao parana
# 0  2019     SP  45.9         100        True
# 1  2019     MG  21.2           1        True
# 2  2019     PR  16.9           2       False
# 3  2020     SP  46.6           3        True
# 4  2020     MG  21.4           4        True
# 5  2020     PR  17.3           5       False

# %% [markdown]
# ## Excluir Coluna

# %%
del df2["nao parana"]

# %%
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9         100
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %% [markdown]
# ## Entender o DataFrame

# %%
df2.shape
# Out:
# (6, 4)

# %%
df2.shape[0]
# Out:
# 6

# %%
df2.shape[1]
# Out:
# 4

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ano', 'estado', 'pop', 'estimativa'], dtype='object')

# %%
df2.count()
# Out:
# ano           6
# estado        6
# pop           6
# estimativa    6
# dtype: int64

# %% [markdown]
# ## Alterar Informações das Colunas

# %%
df2
df2.columns = ["ANO", "ESTADO", "POPULAÇÃO", "ESTIMATIVA"]
df2
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 0  2019     SP       45.9         100
# 1  2019     MG       21.2           1
# 2  2019     PR       16.9           2
# 3  2020     SP       46.6           3
# 4  2020     MG       21.4           4
# 5  2020     PR       17.3           5

# %% [markdown]
# ## Análise do DataFrame

# %%
df2.describe()
df2.describe(include="all")
# Out:
#                 ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# count      6.000000      6   6.000000    6.000000
# unique          NaN      3        NaN         NaN
# top             NaN     SP        NaN         NaN
# freq            NaN      2        NaN         NaN
# mean    2019.500000    NaN  28.216667   19.166667
# std        0.547723    NaN  14.096725   39.625329
# min     2019.000000    NaN  16.900000    1.000000
# 25%     2019.000000    NaN  18.275000    2.250000
# 50%     2019.500000    NaN  21.300000    3.500000
# 75%     2020.000000    NaN  39.775000    4.750000
# max     2020.000000    NaN  46.600000  100.000000

# %% [markdown]
# ## Alterar Valores e Consultar Dados

# %%
df2["ANO"]
df2["ANO"] = df2["ANO"] + 2
df2
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 0  2021     SP       45.9         100
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2[df2["ANO"] > 2023]
df3 = df2[df2["ANO"] > 2023]
df3
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 3  2024     SP       46.6           3
# 4  2024     MG       21.4           4
# 5  2024     PR       17.3           5
# Empty DataFrame
# Columns: [ANO, ESTADO, POPULAÇÃO, ESTIMATIVA]
# Index: []

# %% [markdown]
# ## Ver Dados de Linhas

# %%
df2
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 0  2021     SP       45.9         100
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2.iloc[0]
# Out:
# ANO           2021
# ESTADO          SP
# POPULAÇÃO     45.9
# ESTIMATIVA     100
# Name: 0, dtype: object

# %%
df2.iloc[:]
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 0  2021     SP       45.9         100
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2
# 3  2022     SP       46.6           3
# 4  2022     MG       21.4           4
# 5  2022     PR       17.3           5

# %%
df2.iloc[1:3]
# Out:
#     ANO ESTADO  POPULAÇÃO  ESTIMATIVA
# 1  2021     MG       21.2           1
# 2  2021     PR       16.9           2

# %%
# Seleção de Linhas e Colunas
df2.iloc[1:3, [1,2]]
# Out:
#   ESTADO  POPULAÇÃO
# 1     MG       21.2
# 2     PR       16.9
